# %% [markdown]
# # TCM Prescription Review — ML Experiments
#
# 1. `npm run export:features`
# 2. Load `experiments/data/tcm/features_v1.csv`
# 3. Compare models via `experiments/tcm/train.py`

# %%
import pandas as pd
df = pd.read_csv('../../data/tcm/features_v1.csv')
df.head()
